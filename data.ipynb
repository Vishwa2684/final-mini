# %%
from ultralytics import YOLO
import os
import cv2
from utils.prepare import prepFaces

# %%
model = YOLO('./models/yolov11n-face.pt').to('cpu')

# %%
data = prepFaces('./students','./student_faces',model)

# %%
data.process()
# Out:
# image 1/1 c:\Users\vishw\Desktop\mini project\automated-attendance\students\245322748034\IMG-20221129-WA0004.jpg: 640x480 1 face, 226.0ms
# Speed: 10.0ms preprocess, 226.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\vishw\Desktop\mini project\automated-attendance\students\245322748034\IMG-20230220-WA0012.jpg: 640x320 1 face, 102.5ms
# Speed: 2.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 c:\Users\vishw\Desktop\mini project\automated-attendance\students\245322748034\IMG-20230220-WA0019.jpg: 640x480 2 faces, 123.3ms
# Speed: 3.0ms preprocess, 123.3ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\vishw\Desktop\mini project\automated-attendance\students\245322748034\IMG-20231019-WA0018.jpg: 384x640 1 face, 112.6ms
# Speed: 1.0ms preprocess, 112.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
